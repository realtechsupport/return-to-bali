# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("../find/bali26samples/jackfruit2.jpg", 0)

# %%
plt.imshow(img, cmap='gray')

# %%
height, width = img.shape

# %%
mask = np.zeros((height+2, width+2), np.uint8)
flooded = img.copy()
seed_pt = (800,600)
flags = 8
fill_value = 255
# flags |= (fill_value<<8)
# flags |= cv2.FLOODFILL_MASK_ONLY
flags |= cv2.FLOODFILL_FIXED_RANGE

cv2.floodFill(flooded, mask, seed_pt, (0,255,0), (10), (13), flags)
# cv2.floodFill(flooded, mask, seed_pt, (0,255,0), (11,11,11), (13, 13,13), flags)
# cv2.floodFill(flooded, mask, seed_pt, (255,0,0), (15,15,15), (12,12,12), flags)
print ("done")
# Out:
# done

# %%
# cv2.circle(flooded, seed_pt, 2, (255,0,0), -1)
plt.imshow(flooded)

# %%
# cv2.circle(mask, seed_pt, 10, (0, 255, 0), -1)
plt.imshow(mask)

# %%
seed_pt = (1000,700)
a = cv2.floodFill(flooded, mask, seed_pt, (0,255,0), (11,11,11), (11, 11,11), flags)
plt.imshow(mask)

# %%
img[500][800]
# Out:
# array([ 93, 183, 200], dtype=uint8)

# %%
plt.imshow(img[500:600])

# %%
test = blur[400:700, 500:1000]

# %%
plt.imshow(test, cmap='gray')
